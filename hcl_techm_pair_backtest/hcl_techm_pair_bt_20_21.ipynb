# %%
import numpy as np 
import pandas as pd
import datetime
import matplotlib.pyplot as plt

# %%
df_1=pd.read_csv('/Users/divyansh/Documents/ACA/NIfty_50_Stocks_min_data_17_23/HCLTECH_clean.csv')
df_2=pd.read_csv('/Users/divyansh/Documents/ACA/NIfty_50_Stocks_min_data_17_23/TECHM.csv')

# %%
df_1
# Out:
#         Unnamed: 0                       date     open     high      low  \
# 0                0  2017-01-02 09:15:00+05:30   411.55   412.85   411.15
# 1                1  2017-01-02 09:16:00+05:30   412.55   413.15   412.25
# 2                2  2017-01-02 09:17:00+05:30   412.80   413.50   412.80
# 3                3  2017-01-02 09:18:00+05:30   413.05   413.70   412.70
# 4                4  2017-01-02 09:19:00+05:30   413.70   414.10   413.10
# ...            ...                        ...      ...      ...      ...
# 596476        4120  2023-06-13 15:25:00+05:30  1130.60  1131.00  1130.50
# 596477        4121  2023-06-13 15:26:00+05:30  1130.90  1131.50  1130.30
# 596478        4122  2023-06-13 15:27:00+05:30  1130.55  1132.15  1130.00
# 596479        4123  2023-06-13 15:28:00+05:30  1130.70  1131.70  1130.00
# 596480        4124  2023-06-13 15:29:00+05:30  1130.30  1131.20  1130.00
#
#           close  volume
# 0        412.65    3129
# 1        412.80    1231
# 2        413.05    1902
# 3        413.70    1846
# 4        414.10    2103
# ...         ...     ...
# 596476  1130.55    7429
# 596477  1130.55    8841
# 596478  1130.85   13319
# 596479  1130.45    6223
# 596480  1131.20    4621
#
# [596481 rows x 7 columns]

# %%
df_1['date'] = pd.to_datetime(df_1['date'])
start_date = pd.to_datetime('2020-01-01 09:15:00+05:30')
end_date = pd.to_datetime('2021-12-31 15:29:00+05:30')
df_s1 = df_1[(df_1['date'] >= start_date) & (df_1['date'] <= end_date)]

# %%
df_s1
# Out:
#         Unnamed: 0                      date     open     high      low  \
# 275966        3750 2020-01-01 09:15:00+05:30   569.40   570.40   567.65
# 275967        3751 2020-01-01 09:16:00+05:30   570.00   570.20   569.10
# 275968        3752 2020-01-01 09:17:00+05:30   569.40   569.80   567.55
# 275969        3753 2020-01-01 09:18:00+05:30   567.80   568.90   567.60
# 275970        3754 2020-01-01 09:19:00+05:30   568.50   569.60   567.05
# ...            ...                       ...      ...      ...      ...
# 462557        7494 2021-12-31 15:25:00+05:30  1317.65  1318.00  1317.15
# 462558        7495 2021-12-31 15:26:00+05:30  1317.90  1318.35  1317.60
# 462559        7496 2021-12-31 15:27:00+05:30  1318.30  1319.40  1318.00
# 462560        7497 2021-12-31 15:28:00+05:30  1319.35  1322.85  1317.25
# 462561        7498 2021-12-31 15:29:00+05:30  1318.00  1320.05  1317.80
#
#           close  volume
# 275966   570.00    4211
# 275967   569.25    3035
# 275968   567.90    8360
# 275969   568.50    8043
# 275970   569.40   12774
# ...         ...     ...
# 462557  1317.95   16857
# 462558  1318.35   10114
# 462559  1319.25   11837
# 462560  1317.80   33370
# 462561  1319.45   17956
#
# [186596 rows x 7 columns]

# %%
df_s1.drop('Unnamed: 0',axis=1,inplace=True)
df_s1.drop('volume',axis=1,inplace=True)
# Out:
# /var/folders/_6/8l3zp3t56nx53rdl7c4zh9z40000gn/T/ipykernel_23212/2784357362.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_s1.drop('Unnamed: 0',axis=1,inplace=True)
# /var/folders/_6/8l3zp3t56nx53rdl7c4zh9z40000gn/T/ipykernel_23212/2784357362.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_s1.drop('volume',axis=1,inplace=True)

# %%
df_s1
# Out:
#                             date     open     high      low    close
# 275966 2020-01-01 09:15:00+05:30   569.40   570.40   567.65   570.00
# 275967 2020-01-01 09:16:00+05:30   570.00   570.20   569.10   569.25
# 275968 2020-01-01 09:17:00+05:30   569.40   569.80   567.55   567.90
# 275969 2020-01-01 09:18:00+05:30   567.80   568.90   567.60   568.50
# 275970 2020-01-01 09:19:00+05:30   568.50   569.60   567.05   569.40
# ...                          ...      ...      ...      ...      ...
# 462557 2021-12-31 15:25:00+05:30  1317.65  1318.00  1317.15  1317.95
# 462558 2021-12-31 15:26:00+05:30  1317.90  1318.35  1317.60  1318.35
# 462559 2021-12-31 15:27:00+05:30  1318.30  1319.40  1318.00  1319.25
# 462560 2021-12-31 15:28:00+05:30  1319.35  1322.85  1317.25  1317.80
# 462561 2021-12-31 15:29:00+05:30  1318.00  1320.05  1317.80  1319.45
#
# [186596 rows x 5 columns]

# %%
df_s1['Date']=df_s1['date'].dt.date
df_s1['Time']=df_s1['date'].dt.time
df_s1.drop(['date'],axis=1,inplace=True)
# Out:
# /var/folders/_6/8l3zp3t56nx53rdl7c4zh9z40000gn/T/ipykernel_23212/1157768182.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_s1['Date']=df_s1['date'].dt.date
# /var/folders/_6/8l3zp3t56nx53rdl7c4zh9z40000gn/T/ipykernel_23212/1157768182.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_s1['Time']=df_s1['date'].dt.time
# /var/folders/_6/8l3zp3t56nx53rdl7c4zh9z40000gn/T/ipykernel_23212/1157768182.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_s1.drop(['date'],axis=1,inplace=True)

# %%
df_s1
# Out:
#            open     high      low    close        Date      Time
# 275966   569.40   570.40   567.65   570.00  2020-01-01  09:15:00
# 275967   570.00   570.20   569.10   569.25  2020-01-01  09:16:00
# 275968   569.40   569.80   567.55   567.90  2020-01-01  09:17:00
# 275969   567.80   568.90   567.60   568.50  2020-01-01  09:18:00
# 275970   568.50   569.60   567.05   569.40  2020-01-01  09:19:00
# ...         ...      ...      ...      ...         ...       ...
# 462557  1317.65  1318.00  1317.15  1317.95  2021-12-31  15:25:00
# 462558  1317.90  1318.35  1317.60  1318.35  2021-12-31  15:26:00
# 462559  1318.30  1319.40  1318.00  1319.25  2021-12-31  15:27:00
# 462560  1319.35  1322.85  1317.25  1317.80  2021-12-31  15:28:00
# 462561  1318.00  1320.05  1317.80  1319.45  2021-12-31  15:29:00
#
# [186596 rows x 6 columns]

# %%
df_2['date'] = pd.to_datetime(df_2['date'])
start_date = pd.to_datetime('2020-01-01 09:15:00+05:30')
end_date = pd.to_datetime('2021-12-31 15:29:00+05:30')
df_s2 = df_2[(df_2['date'] >= start_date) & (df_2['date'] <= end_date)]

# %%
df_s2
# Out:
#         Unnamed: 0                      date     open     high      low  \
# 275966        3750 2020-01-01 09:15:00+05:30   766.00   766.00   763.75
# 275967        3751 2020-01-01 09:16:00+05:30   765.90   766.80   764.50
# 275968        3752 2020-01-01 09:17:00+05:30   765.50   765.85   764.50
# 275969        3753 2020-01-01 09:18:00+05:30   765.80   766.20   765.50
# 275970        3754 2020-01-01 09:19:00+05:30   765.75   765.75   764.40
# ...            ...                       ...      ...      ...      ...
# 462557        7494 2021-12-31 15:25:00+05:30  1790.15  1791.20  1789.95
# 462558        7495 2021-12-31 15:26:00+05:30  1790.65  1792.00  1790.65
# 462559        7496 2021-12-31 15:27:00+05:30  1791.05  1791.45  1790.10
# 462560        7497 2021-12-31 15:28:00+05:30  1791.00  1791.00  1790.00
# 462561        7498 2021-12-31 15:29:00+05:30  1790.10  1792.00  1789.35
#
#           close  volume
# 275966   765.40   12565
# 275967   764.95   24957
# 275968   765.70    8301
# 275969   765.50    7435
# 275970   765.00    6345
# ...         ...     ...
# 462557  1791.15    9323
# 462558  1791.05    6052
# 462559  1790.80   15599
# 462560  1791.00   15653
# 462561  1792.00    8029
#
# [186596 rows x 7 columns]

# %%
df_s2.drop('Unnamed: 0',axis=1,inplace=True)
df_s2.drop('volume',axis=1,inplace=True)
# Out:
# /var/folders/_6/8l3zp3t56nx53rdl7c4zh9z40000gn/T/ipykernel_23212/3753465639.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_s2.drop('Unnamed: 0',axis=1,inplace=True)
# /var/folders/_6/8l3zp3t56nx53rdl7c4zh9z40000gn/T/ipykernel_23212/3753465639.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_s2.drop('volume',axis=1,inplace=True)

# %%
df_s2
# Out:
#                             date     open     high      low    close
# 275966 2020-01-01 09:15:00+05:30   766.00   766.00   763.75   765.40
# 275967 2020-01-01 09:16:00+05:30   765.90   766.80   764.50   764.95
# 275968 2020-01-01 09:17:00+05:30   765.50   765.85   764.50   765.70
# 275969 2020-01-01 09:18:00+05:30   765.80   766.20   765.50   765.50
# 275970 2020-01-01 09:19:00+05:30   765.75   765.75   764.40   765.00
# ...                          ...      ...      ...      ...      ...
# 462557 2021-12-31 15:25:00+05:30  1790.15  1791.20  1789.95  1791.15
# 462558 2021-12-31 15:26:00+05:30  1790.65  1792.00  1790.65  1791.05
# 462559 2021-12-31 15:27:00+05:30  1791.05  1791.45  1790.10  1790.80
# 462560 2021-12-31 15:28:00+05:30  1791.00  1791.00  1790.00  1791.00
# 462561 2021-12-31 15:29:00+05:30  1790.10  1792.00  1789.35  1792.00
#
# [186596 rows x 5 columns]

# %%
df_s2['Date']=df_s2['date'].dt.date
df_s2['Time']=df_s2['date'].dt.time
df_s2.drop(['date'],axis=1,inplace=True)
# Out:
# /var/folders/_6/8l3zp3t56nx53rdl7c4zh9z40000gn/T/ipykernel_23212/3018108217.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_s2['Date']=df_s2['date'].dt.date
# /var/folders/_6/8l3zp3t56nx53rdl7c4zh9z40000gn/T/ipykernel_23212/3018108217.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_s2['Time']=df_s2['date'].dt.time
# /var/folders/_6/8l3zp3t56nx53rdl7c4zh9z40000gn/T/ipykernel_23212/3018108217.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_s2.drop(['date'],axis=1,inplace=True)

# %%
df_s2
# Out:
#            open     high      low    close        Date      Time
# 275966   766.00   766.00   763.75   765.40  2020-01-01  09:15:00
# 275967   765.90   766.80   764.50   764.95  2020-01-01  09:16:00
# 275968   765.50   765.85   764.50   765.70  2020-01-01  09:17:00
# 275969   765.80   766.20   765.50   765.50  2020-01-01  09:18:00
# 275970   765.75   765.75   764.40   765.00  2020-01-01  09:19:00
# ...         ...      ...      ...      ...         ...       ...
# 462557  1790.15  1791.20  1789.95  1791.15  2021-12-31  15:25:00
# 462558  1790.65  1792.00  1790.65  1791.05  2021-12-31  15:26:00
# 462559  1791.05  1791.45  1790.10  1790.80  2021-12-31  15:27:00
# 462560  1791.00  1791.00  1790.00  1791.00  2021-12-31  15:28:00
# 462561  1790.10  1792.00  1789.35  1792.00  2021-12-31  15:29:00
#
# [186596 rows x 6 columns]

# %%
df=pd.DataFrame()
df['ratio']=df_s1['close']/df_s2['close']
df['Date']=df_s1['Date']
df['Time']=df_s1['Time']

# %%
df
# Out:
#            ratio        Date      Time
# 275966  0.744709  2020-01-01  09:15:00
# 275967  0.744166  2020-01-01  09:16:00
# 275968  0.741674  2020-01-01  09:17:00
# 275969  0.742652  2020-01-01  09:18:00
# 275970  0.744314  2020-01-01  09:19:00
# ...          ...         ...       ...
# 462557  0.735812  2021-12-31  15:25:00
# 462558  0.736077  2021-12-31  15:26:00
# 462559  0.736682  2021-12-31  15:27:00
# 462560  0.735790  2021-12-31  15:28:00
# 462561  0.736300  2021-12-31  15:29:00
#
# [186596 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# ratio    0
# Date     0
# Time     0
# dtype: int64

# %%
mean=np.mean(df['ratio'])
stdev=np.std(df['ratio'])

# %%
print(mean)
print(stdev)
# Out:
# 0.9096100671943399
# 0.10514363053016104

# %%
from datetime import timedelta

# %%
df.plot(x='Date',y='ratio',kind='line',label='Spread Ratio')
plt.axhline(mean, color='black', linestyle='--', label='Mean')
plt.axhline(mean - stdev, color='red', linestyle='--', label='-1 Std Dev')
plt.axhline(mean - (2*stdev), color='red', linestyle='--', label='-2 Std Dev')
plt.axhline(mean - (1.5*stdev), color='red', linestyle='--', label='-2 Std Dev')
plt.axhline(mean + stdev, color='green', linestyle='--', label='+1 Std Dev')
plt.axhline(mean + (2*stdev), color='green', linestyle='--', label='+2 Std Dev')
plt.axhline(mean + (1.5*stdev), color='green', linestyle='--', label='+1 Std Dev')
plt.title('Spread Ratio')
plt.xticks(rotation=45)
plt.show()

# %%
results=[]
total_pnl=0
position_1=0
position_2=0
sl=0
exit_1=None
exit_2=None
exit_date=None
exit_time=None
pnl=0
# entry_date=None
# entry_time=None
trade_status = []
dates=df['Date'].unique()

for date in dates:
    Date=date
    daily_date=df[df['Date']==date]
    daily_date_s1=df_s1[df_s1['Date']==date]
    daily_date_s2=df_s2[df_s2['Date']==date]
    
    time_range=daily_date[(daily_date['Time']>pd.to_datetime('9:15:00').time()) & (daily_date['Time']<pd.to_datetime('15:30:00').time())]['Time'].unique()
    
    for time in time_range:
        if (position_2 ==0) and (daily_date[daily_date['Time']==time]['ratio'].iloc[0]<=(mean-(2*stdev))):
            position_2=1
            signal='Buy'
            entry_1=daily_date_s1[daily_date_s1['Time']==time]['close'].iloc[0]
            entry_2=daily_date_s2[daily_date_s2['Time']==time]['close'].iloc[0]
            entry_date=date
            entry_time=time
#             print(signal)
#             print(entry_1)
#             print(entry_2)
            
        elif (position_2==1):
            sl=mean-(2.75*stdev)
            if (daily_date[daily_date['Time']==time]['ratio'].iloc[0]>=(mean)):
                position_2==0
                trade_status='Trade complete'
                exit_1=daily_date_s1[daily_date_s1['Time']==time]['close'].iloc[0]
                exit_2=daily_date_s2[daily_date_s2['Time']==time]['close'].iloc[0]
                exit_date=date
                exit_time=time
                pnl=700*(exit_1-entry_1)+600*(entry_2-exit_2)
                #print(pnl)
#                 print(signal)
#                 print(exit_1)
#                 print(exit_2)
                
            elif (daily_date[daily_date['Time']==time]['ratio'].iloc[0]<=sl):  
                position_2==0
                trade_status='SL hit'
                exit_1=daily_date_s1[daily_date_s1['Time']==time]['close'].iloc[0]
                exit_2=daily_date_s2[daily_date_s2['Time']==time]['close'].iloc[0]
                exit_date=date
                exit_time=time
                pnl=700*(exit_1-entry_1)+600*(entry_2-exit_2)
                #print(pnl)
#                 print(signal)
#                 print(exit_1)
#                 print(exit_2)
            
                
            #total_pnl+=pnl
            
        #print(total_pnl)
                
                
    result = {
        'Date': date,
        'signal': signal,
        'Trade status': trade_status,
        'Entry Price s1': entry_1,
        'Entry Price s2': entry_2,
        'Entry Date': entry_date,
        'Entry time': entry_time,
        'Exit Price s1': exit_1,
        'Exit Price s2': exit_2,
        'Exit Date': exit_date,
        'Exit Time': exit_time,
        'PnL': pnl,
        'Total PnL': total_pnl
    }     

    results.append(result)
results_df=pd.DataFrame(results)
print(results_df)
# Out:
#            Date signal    Trade status  Entry Price s1  Entry Price s2  \
# 0    2020-01-01    Buy              []          569.25          764.95
# 1    2020-01-02    Buy              []          569.25          764.95
# 2    2020-01-03    Buy              []          569.25          764.95
# 3    2020-01-06    Buy              []          569.25          764.95
# 4    2020-01-07    Buy              []          569.25          764.95
# ..          ...    ...             ...             ...             ...
# 495  2021-12-27    Buy  Trade complete          390.05          560.30
# 496  2021-12-28    Buy  Trade complete          390.05          560.30
# 497  2021-12-29    Buy  Trade complete          390.05          560.30
# 498  2021-12-30    Buy  Trade complete          390.05          560.30
# 499  2021-12-31    Buy  Trade complete          390.05          560.30
#
#      Entry Date Entry time  Exit Price s1  Exit Price s2   Exit Date  \
# 0    2020-01-01   09:16:00            NaN            NaN        None
# 1    2020-01-01   09:16:00            NaN            NaN        None
# 2    2020-01-01   09:16:00            NaN            NaN        None
# 3    2020-01-01   09:16:00            NaN            NaN        None
# 4    2020-01-01   09:16:00            NaN            NaN        None
# ..          ...        ...            ...            ...         ...
# 495  2020-03-19   09:16:00         1254.9         1377.8  2021-10-12
# 496  2020-03-19   09:16:00         1254.9         1377.8  2021-10-12
# 497  2020-03-19   09:16:00         1254.9         1377.8  2021-10-12
# 498  2020-03-19   09:16:00         1254.9         1377.8  2021-10-12
# 499  2020-03-19   09:16:00         1254.9         1377.8  2021-10-12
#
#     Exit Time       PnL  Total PnL
# 0        None       0.0          0
# 1        None       0.0          0
# 2        None       0.0          0
# 3        None       0.0          0
# 4        None       0.0          0
# ..        ...       ...        ...
# 495  15:29:00  114895.0          0
# 496  15:29:00  114895.0          0
# 497  15:29:00  114895.0          0
# 498  15:29:00  114895.0          0
# 499  15:29:00  114895.0          0
#
# [500 rows x 13 columns]

# %%
results_df.to_csv('pairtrade_2_2sdbuy.csv')
