# %%
import numpy as np 
import pandas as pd
import datetime
import matplotlib.pyplot as plt

# %%
df_1=pd.read_csv('/Users/divyansh/Documents/ACA/Nifty_200_Stocks_min_data_17_23/HDFCBANK.csv')
df_2=pd.read_csv('/Users/divyansh/Documents/ACA/Nifty_200_Stocks_min_data_17_23/ICICIBANK.csv')

# %%
df_1
# Out:
#         Unnamed: 0                       date     open     high      low  \
# 0                0  2017-01-02 09:15:00+05:30   605.00   605.00   601.00
# 1                1  2017-01-02 09:16:00+05:30   601.45   602.35   601.45
# 2                2  2017-01-02 09:17:00+05:30   601.95   602.35   599.25
# 3                3  2017-01-02 09:18:00+05:30   599.25   600.35   599.00
# 4                4  2017-01-02 09:19:00+05:30   600.35   600.50   599.75
# ...            ...                        ...      ...      ...      ...
# 596477        4120  2023-06-13 15:25:00+05:30  1607.35  1607.60  1607.30
# 596478        4121  2023-06-13 15:26:00+05:30  1607.60  1607.85  1607.55
# 596479        4122  2023-06-13 15:27:00+05:30  1607.75  1608.65  1607.70
# 596480        4123  2023-06-13 15:28:00+05:30  1608.00  1608.55  1608.00
# 596481        4124  2023-06-13 15:29:00+05:30  1608.10  1609.00  1606.10
#
#           close  volume
# 0        601.45    7033
# 1        602.00    3026
# 2        599.25    4129
# 3        600.35     687
# 4        600.00    2221
# ...         ...     ...
# 596477  1607.55   54117
# 596478  1607.80   42219
# 596479  1608.10  111022
# 596480  1608.05   59165
# 596481  1607.95   53996
#
# [596482 rows x 7 columns]

# %%
df_1['date'] = pd.to_datetime(df_1['date'])
start_date = pd.to_datetime('2021-01-01 09:15:00+05:30')
end_date = pd.to_datetime('2023-06-13 15:29:00+05:30')
df_s1 = df_1[(df_1['date'] >= start_date) & (df_1['date'] <= end_date)]

# %%
df_s1.drop('Unnamed: 0',axis=1,inplace=True)
df_s1.drop('volume',axis=1,inplace=True)
# Out:
# /var/folders/_6/8l3zp3t56nx53rdl7c4zh9z40000gn/T/ipykernel_30659/2784357362.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_s1.drop('Unnamed: 0',axis=1,inplace=True)
# /var/folders/_6/8l3zp3t56nx53rdl7c4zh9z40000gn/T/ipykernel_30659/2784357362.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_s1.drop('volume',axis=1,inplace=True)

# %%
df_s1['Date']=df_s1['date'].dt.date
df_s1['Time']=df_s1['date'].dt.time
df_s1.drop(['date'],axis=1,inplace=True)
# Out:
# /var/folders/_6/8l3zp3t56nx53rdl7c4zh9z40000gn/T/ipykernel_30659/1157768182.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_s1['Date']=df_s1['date'].dt.date
# /var/folders/_6/8l3zp3t56nx53rdl7c4zh9z40000gn/T/ipykernel_30659/1157768182.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_s1['Time']=df_s1['date'].dt.time
# /var/folders/_6/8l3zp3t56nx53rdl7c4zh9z40000gn/T/ipykernel_30659/1157768182.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_s1.drop(['date'],axis=1,inplace=True)

# %%
df_s1
# Out:
#            open     high      low    close        Date      Time
# 370030  1440.00  1441.10  1434.30  1440.65  2021-01-01  09:15:00
# 370031  1440.35  1441.80  1436.00  1436.00  2021-01-01  09:16:00
# 370032  1437.00  1438.65  1436.50  1438.50  2021-01-01  09:17:00
# 370033  1438.50  1438.75  1437.00  1437.25  2021-01-01  09:18:00
# 370034  1437.20  1437.20  1435.15  1436.90  2021-01-01  09:19:00
# ...         ...      ...      ...      ...         ...       ...
# 596477  1607.35  1607.60  1607.30  1607.55  2023-06-13  15:25:00
# 596478  1607.60  1607.85  1607.55  1607.80  2023-06-13  15:26:00
# 596479  1607.75  1608.65  1607.70  1608.10  2023-06-13  15:27:00
# 596480  1608.00  1608.55  1608.00  1608.05  2023-06-13  15:28:00
# 596481  1608.10  1609.00  1606.10  1607.95  2023-06-13  15:29:00
#
# [226452 rows x 6 columns]

# %%
df_s1.reset_index(inplace=True)

# %%
df_s1
# Out:
#          index     open     high      low    close        Date      Time
# 0       370030  1440.00  1441.10  1434.30  1440.65  2021-01-01  09:15:00
# 1       370031  1440.35  1441.80  1436.00  1436.00  2021-01-01  09:16:00
# 2       370032  1437.00  1438.65  1436.50  1438.50  2021-01-01  09:17:00
# 3       370033  1438.50  1438.75  1437.00  1437.25  2021-01-01  09:18:00
# 4       370034  1437.20  1437.20  1435.15  1436.90  2021-01-01  09:19:00
# ...        ...      ...      ...      ...      ...         ...       ...
# 226447  596477  1607.35  1607.60  1607.30  1607.55  2023-06-13  15:25:00
# 226448  596478  1607.60  1607.85  1607.55  1607.80  2023-06-13  15:26:00
# 226449  596479  1607.75  1608.65  1607.70  1608.10  2023-06-13  15:27:00
# 226450  596480  1608.00  1608.55  1608.00  1608.05  2023-06-13  15:28:00
# 226451  596481  1608.10  1609.00  1606.10  1607.95  2023-06-13  15:29:00
#
# [226452 rows x 7 columns]

# %%
df_2['date'] = pd.to_datetime(df_2['date'])
start_date = pd.to_datetime('2021-01-01 09:15:00+05:30')
end_date = pd.to_datetime('2023-06-13 15:29:00+05:30')
df_s2 = df_2[(df_2['date'] >= start_date) & (df_2['date'] <= end_date)]

# %%
df_s2.drop('Unnamed: 0',axis=1,inplace=True)
df_s2.drop('volume',axis=1,inplace=True)
# Out:
# /var/folders/_6/8l3zp3t56nx53rdl7c4zh9z40000gn/T/ipykernel_30659/3753465639.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_s2.drop('Unnamed: 0',axis=1,inplace=True)
# /var/folders/_6/8l3zp3t56nx53rdl7c4zh9z40000gn/T/ipykernel_30659/3753465639.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_s2.drop('volume',axis=1,inplace=True)

# %%
df_s2['Date']=df_s2['date'].dt.date
df_s2['Time']=df_s2['date'].dt.time
df_s2.drop(['date'],axis=1,inplace=True)
# Out:
# /var/folders/_6/8l3zp3t56nx53rdl7c4zh9z40000gn/T/ipykernel_30659/3018108217.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_s2['Date']=df_s2['date'].dt.date
# /var/folders/_6/8l3zp3t56nx53rdl7c4zh9z40000gn/T/ipykernel_30659/3018108217.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_s2['Time']=df_s2['date'].dt.time
# /var/folders/_6/8l3zp3t56nx53rdl7c4zh9z40000gn/T/ipykernel_30659/3018108217.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_s2.drop(['date'],axis=1,inplace=True)

# %%
df_s2
# Out:
#           open    high     low   close        Date      Time
# 370029  535.55  536.05  535.05  535.40  2021-01-01  09:15:00
# 370030  535.35  535.65  535.05  535.15  2021-01-01  09:16:00
# 370031  535.20  535.50  534.75  535.30  2021-01-01  09:17:00
# 370032  535.55  536.00  535.25  535.95  2021-01-01  09:18:00
# 370033  535.95  535.95  535.55  535.90  2021-01-01  09:19:00
# ...        ...     ...     ...     ...         ...       ...
# 596476  945.50  945.50  945.25  945.30  2023-06-13  15:25:00
# 596477  945.50  945.50  944.75  945.00  2023-06-13  15:26:00
# 596478  944.95  945.20  944.30  944.60  2023-06-13  15:27:00
# 596479  944.60  944.85  943.00  944.00  2023-06-13  15:28:00
# 596480  943.85  944.95  943.25  943.75  2023-06-13  15:29:00
#
# [226452 rows x 6 columns]

# %%
df_s2.reset_index(inplace=True)

# %%
df_s2
# Out:
#          index    open    high     low   close        Date      Time
# 0       370029  535.55  536.05  535.05  535.40  2021-01-01  09:15:00
# 1       370030  535.35  535.65  535.05  535.15  2021-01-01  09:16:00
# 2       370031  535.20  535.50  534.75  535.30  2021-01-01  09:17:00
# 3       370032  535.55  536.00  535.25  535.95  2021-01-01  09:18:00
# 4       370033  535.95  535.95  535.55  535.90  2021-01-01  09:19:00
# ...        ...     ...     ...     ...     ...         ...       ...
# 226447  596476  945.50  945.50  945.25  945.30  2023-06-13  15:25:00
# 226448  596477  945.50  945.50  944.75  945.00  2023-06-13  15:26:00
# 226449  596478  944.95  945.20  944.30  944.60  2023-06-13  15:27:00
# 226450  596479  944.60  944.85  943.00  944.00  2023-06-13  15:28:00
# 226451  596480  943.85  944.95  943.25  943.75  2023-06-13  15:29:00
#
# [226452 rows x 7 columns]

# %%
df=pd.DataFrame()
df['ratio']=df_s1['close']/df_s2['close']
df['Date']=df_s1['Date']
df['Time']=df_s1['Time']

# %%
df
# Out:
#            ratio        Date      Time
# 0       2.690792  2021-01-01  09:15:00
# 1       2.683360  2021-01-01  09:16:00
# 2       2.687278  2021-01-01  09:17:00
# 3       2.681687  2021-01-01  09:18:00
# 4       2.681284  2021-01-01  09:19:00
# ...          ...         ...       ...
# 226447  1.700571  2023-06-13  15:25:00
# 226448  1.701376  2023-06-13  15:26:00
# 226449  1.702414  2023-06-13  15:27:00
# 226450  1.703443  2023-06-13  15:28:00
# 226451  1.703788  2023-06-13  15:29:00
#
# [226452 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# ratio    0
# Date     0
# Time     0
# dtype: int64

# %%
mean=np.mean(df['ratio'])
stdev=np.std(df['ratio'])

# %%
print(mean)
print(stdev)
# Out:
# 2.022810856312022
# 0.2848270649693524

# %%
df.plot(x='Date',y='ratio',kind='line',label='Spread Ratio')
plt.axhline(mean, color='black', linestyle='--', label='Mean')
plt.axhline(mean - stdev, color='red', linestyle='--', label='-1 Std Dev')
plt.axhline(mean - (2*stdev), color='red', linestyle='--', label='-2 Std Dev')
plt.axhline(mean - (1.5*stdev), color='red', linestyle='--', label='-2 Std Dev')
plt.axhline(mean + stdev, color='green', linestyle='--', label='+1 Std Dev')
plt.axhline(mean + (2*stdev), color='green', linestyle='--', label='+2 Std Dev')
plt.axhline(mean + (1.5*stdev), color='green', linestyle='--', label='+1 Std Dev')
plt.title('Spread Ratio')
plt.xticks(rotation=45)
plt.show()

# %%
results=[]
total_pnl=0
position_1=0
sl=0
signal=None
trade_status=None
entry_1=None
entry_2=None
entry_date=None
entry_time=None
exit_1=None
exit_2=None
exit_date=None
exit_time=None
pnl=None
# entry_date=None
# entry_time=None

dates=df['Date'].unique()

for date in dates:
    Date=date
    daily_date=df[df['Date']==date]
    daily_date_s1=df_s1[df_s1['Date']==date]
    daily_date_s2=df_s2[df_s2['Date']==date]
    
    time_range=daily_date[(daily_date['Time']>pd.to_datetime('9:15:00').time()) & (daily_date['Time']<pd.to_datetime('15:30:00').time())]['Time'].unique()
    
    for time in time_range:
        if (position_1 ==0) and (daily_date[daily_date['Time']==time]['ratio'].iloc[0]>=(mean+(2*stdev))):
            position_1=1
            signal='Sell'
            entry_1=daily_date_s1[daily_date_s1['Time']==time]['close'].iloc[0]
            entry_2=daily_date_s2[daily_date_s2['Time']==time]['close'].iloc[0]
            entry_date=date
            entry_time=time
            
        elif (position_1==1):
            sl=mean+(2.75*stdev)
            if (daily_date[daily_date['Time']==time]['ratio'].iloc[0]<=(mean)):
                position_1==0
                trade_status='Trade complete'
                exit_1=daily_date_s1[daily_date_s1['Time']==time]['close'].iloc[0]
                exit_2=daily_date_s2[daily_date_s2['Time']==time]['close'].iloc[0]
                exit_date=date
                exit_time=time
                pnl=(entry_1-exit_1)+(exit_2-entry_2)
                
            elif (daily_date[daily_date['Time']==time]['ratio'].iloc[0]>=sl):  
                position_1==0
                trade_status='SL hit'
                exit_1=daily_date_s1[daily_date_s1['Time']==time]['close'].iloc[0]
                exit_2=daily_date_s2[daily_date_s2['Time']==time]['close'].iloc[0]
                exit_date=date
                exit_time=time
                pnl=(entry_1-exit_1)+(exit_2-entry_2)
                
            #total_pnl+=pnl
            
        #print(total_pnl)
                
                
    result = {
        'Date': date,
        'signal' : signal,
        'Trade Status': trade_status,
        'Entry Price s1': entry_1,
        'Entry Price s2': entry_2,
        'Entry Date': entry_date,
        'Entry time': entry_time,
        'Exit Price s1': exit_1,
        'Exit Price s2': exit_2,
        'Exit Date': exit_date,
        'Exit Time': exit_time,
        'PnL': pnl,
    }     

    results.append(result)
results_df=pd.DataFrame(results)
print(results_df)
# Out:
#            Date signal    Trade Status  Entry Price s1  Entry Price s2  \
# 0    2021-01-01   Sell            None          1436.0          535.15
# 1    2021-01-04   Sell            None          1436.0          535.15
# 2    2021-01-05   Sell            None          1436.0          535.15
# 3    2021-01-06   Sell            None          1436.0          535.15
# 4    2021-01-07   Sell            None          1436.0          535.15
# ..          ...    ...             ...             ...             ...
# 601  2023-06-07   Sell  Trade complete          1436.0          535.15
# 602  2023-06-08   Sell  Trade complete          1436.0          535.15
# 603  2023-06-09   Sell  Trade complete          1436.0          535.15
# 604  2023-06-12   Sell  Trade complete          1436.0          535.15
# 605  2023-06-13   Sell  Trade complete          1436.0          535.15
#
#      Entry Date Entry time  Exit Price s1  Exit Price s2   Exit Date  \
# 0    2021-01-01   09:16:00            NaN            NaN        None
# 1    2021-01-01   09:16:00            NaN            NaN        None
# 2    2021-01-01   09:16:00            NaN            NaN        None
# 3    2021-01-01   09:16:00            NaN            NaN        None
# 4    2021-01-01   09:16:00            NaN            NaN        None
# ..          ...        ...            ...            ...         ...
# 601  2021-01-01   09:16:00        1611.00         940.00  2023-06-07
# 602  2021-01-01   09:16:00        1608.80         938.95  2023-06-08
# 603  2021-01-01   09:16:00        1609.50         939.15  2023-06-09
# 604  2021-01-01   09:16:00        1600.90         936.70  2023-06-12
# 605  2021-01-01   09:16:00        1607.95         943.75  2023-06-13
#
#     Exit Time     PnL
# 0        None     NaN
# 1        None     NaN
# 2        None     NaN
# 3        None     NaN
# 4        None     NaN
# ..        ...     ...
# 601  15:29:00  229.85
# 602  15:29:00  231.00
# 603  15:29:00  230.50
# 604  15:29:00  236.65
# 605  15:29:00  236.65
#
# [606 rows x 12 columns]

# %%
results_df.to_csv('pt_icici_hdfc_21-23.csv')

# %%
print(mean+2.75*stdev)
# Out:
# 2.806085284977741
